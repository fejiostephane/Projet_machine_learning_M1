# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt

# %%
import pandas as pd

# Chemin vers ton dataset final propre
CSV_FILE = "MASTER_dataset_all_sensors_CLEAN.csv"

# Chargement du dataset
df = pd.read_csv(CSV_FILE)

# Vérifications immédiates
print("✅ Dataset chargé avec succès")
print("Shape :", df.shape)
print("Colonnes :", df.columns[:5].tolist(), "...", df.columns[-5:].tolist())

# Vérifier que tout est bien numérique (sauf 'cycle')
non_numeric = df.drop(columns=["cycle"]).select_dtypes(exclude=["number"]).columns
print("Colonnes non numériques :", list(non_numeric))

# Aperçu
display(df.head())
# Out:
# ✅ Dataset chargé avec succès
# Shape : (2205, 1946)
# Colonnes : ['cycle', 'PS1_mean_w0', 'PS1_mean_w1', 'PS1_mean_w2', 'PS1_mean_w3'] ... ['VS1_mean', 'VS1_min', 'VS1_max', 'VS1_std', 'VS1_slope']
# Colonnes non numériques : []
#    cycle  PS1_mean_w0  PS1_mean_w1  PS1_mean_w2  PS1_mean_w3  PS1_mean_w4  \
# 0      1     176.8996     184.6420     189.8996     191.3442     191.2833
# 1      2     174.2707     191.3529     191.3024     191.3244     191.2904
# 2      3     174.0188     191.2384     191.2183     191.2233     191.2159
# 3      4     173.6540     191.1975     191.1919     191.1685     191.1353
# 4      5     173.4353     191.2045     191.1586     191.0698     191.1039
#
#    PS1_mean_w5  PS1_mean_w6  PS1_mean_w7  PS1_mean_w8  ...   TS4_mean  \
# 0     191.3120     191.2947     191.3183     191.3116  ...  31.745250
# 1     191.2400     191.2647     191.2463     191.2714  ...  34.493867
# 2     191.2040     191.1968     191.1760     191.2123  ...  35.646150
# ...

# %%
# Chemin vers le dataset final
DATASET_FILE = "FINAL_DATASET_READY_FOR_ML.csv"

# Chargement du dataset
df = pd.read_csv(DATASET_FILE)

# Vérifications essentielles
print("✅ Dataset chargé avec succès")

df.head()
# Out:
# ✅ Dataset chargé avec succès
#    cycle  PS1_mean_w0  PS1_mean_w1  PS1_mean_w2  PS1_mean_w3  PS1_mean_w4  \
# 0      1     176.8996     184.6420     189.8996     191.3442     191.2833
# 1      2     174.2707     191.3529     191.3024     191.3244     191.2904
# 2      3     174.0188     191.2384     191.2183     191.2233     191.2159
# 3      4     173.6540     191.1975     191.1919     191.1685     191.1353
# 4      5     173.4353     191.2045     191.1586     191.0698     191.1039
#
#    PS1_mean_w5  PS1_mean_w6  PS1_mean_w7  PS1_mean_w8  ...  TS4_min  TS4_max  \
# 0     191.3120     191.2947     191.3183     191.3116  ...   30.363   33.594
# 1     191.2400     191.2647     191.2463     191.2714  ...   33.648   35.148
# 2     191.2040     191.1968     191.1760     191.2123  ...   35.098   36.141
# 3     191.1725     191.1252     191.1575     191.0729  ...   36.105   36.988
# 4     191.0707     191.0806     191.0756     191.0682  ...   36.992   37.781
#
# ...
